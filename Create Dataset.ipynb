# %%
import os

# %%
dir = os.getcwd() + '/Dataset/'
c = 0
arr=[]
for i in os.listdir(dir):
    if i[0] == '.':
        continue
    folder = dir + i +'/'
    for j in os.listdir(folder):
        if j[0] == '.':
            continue
        path = folder + j
        arr.append([path,i])

# %%
arr
# Out:
# [['/Users/avdhantyagi/DISK/notebook/Dataset/Land/n02128385_12721.JPEG',
#   'Land'],
#  ['/Users/avdhantyagi/DISK/notebook/Dataset/Land/n02490219_3650.JPEG', 'Land'],
#  ['/Users/avdhantyagi/DISK/notebook/Dataset/Land/n02134084_1921.JPEG', 'Land'],
#  ['/Users/avdhantyagi/DISK/notebook/Dataset/Land/n02115641_13264.JPEG',
#   'Land'],
#  ['/Users/avdhantyagi/DISK/notebook/Dataset/Land/n02391049_356.JPEG', 'Land'],
#  ['/Users/avdhantyagi/DISK/notebook/Dataset/Land/n02493793_1557.JPEG', 'Land'],
#  ['/Users/avdhantyagi/DISK/notebook/Dataset/Land/n02492660_10363.JPEG',
#   'Land'],
#  ['/Users/avdhantyagi/DISK/notebook/Dataset/Land/n02415577_1222.JPEG', 'Land'],
#  ['/Users/avdhantyagi/DISK/notebook/Dataset/Land/n01704323_9386.JPEG', 'Land'],
#  ['/Users/avdhantyagi/DISK/notebook/Dataset/Land/n02395406_75881.JPEG',
#   'Land'],
#  ['/Users/avdhantyagi/DISK/notebook/Dataset/Land/n02397096_1001.JPEG', 'Land'],
# ...

# %%
import pandas as pd
data = pd.DataFrame(arr, columns=['path','class'])

# %%
data
# Out:
#                                                     path       class
# 0      /Users/avdhantyagi/DISK/notebook/Dataset/Land/...        Land
# 1      /Users/avdhantyagi/DISK/notebook/Dataset/Land/...        Land
# 2      /Users/avdhantyagi/DISK/notebook/Dataset/Land/...        Land
# 3      /Users/avdhantyagi/DISK/notebook/Dataset/Land/...        Land
# 4      /Users/avdhantyagi/DISK/notebook/Dataset/Land/...        Land
# ...                                                  ...         ...
# 28209  /Users/avdhantyagi/DISK/notebook/Dataset/Land-...  Land-small
# 28210  /Users/avdhantyagi/DISK/notebook/Dataset/Land-...  Land-small
# 28211  /Users/avdhantyagi/DISK/notebook/Dataset/Land-...  Land-small
# 28212  /Users/avdhantyagi/DISK/notebook/Dataset/Land-...  Land-small
# 28213  /Users/avdhantyagi/DISK/notebook/Dataset/Land-...  Land-small
#
# [28214 rows x 2 columns]

# %%
data.to_csv(os.getcwd()+"/dataset.csv",header=False, index=False)
